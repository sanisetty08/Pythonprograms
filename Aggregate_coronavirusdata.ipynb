# %%
import sqlalchemy
import psycopg2
PostgresDB_URI = 'postgres+psycopg2://postgres:admin@localhost:5432/postgres'

# %%
from sqlalchemy import create_engine 
engine = create_engine(PostgresDB_URI)
connection = engine.connect() 
connection = connection.execution_options(isolation_level="READ COMMITTED") 

from sqlalchemy.sql import text
MyQuery = text("SELECT * FROM \"Coronavirus\"") 
srinurow = connection.execute(MyQuery).fetchall()

# %%
import pandas as pd
import numpy as np

#read the data set
data_df = pd.DataFrame(srinurow)
data_df.columns = ['Country', 'TotalCases', 'NewCases', 'TotalDeaths', 'NewDeaths', 'TotalRecovered', 
                   'ActiveCases', 'SeriousCases', 'TotalCasesPM','DeathsPM', 'TotalTests', 'TestsPM','Population']
data_df
# Out:
#                     Country  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0                       USA    16191184    142256       301760       1935
# 1                     India     9826031     29039       142618        396
# 2                    Brazil     6794910     11367       179897         96
# 3                    Russia     2597711     28585        45893        613
# 4                    France     2351372     13406        57567        412
# 5                        UK     1809455     21672        63506        424
# 6                     Italy     1805873     18727        63387        761
# 7                    Turkey     1780673     32106        15977        226
# 8                     Spain     1741439      7053        47624        280
# 9                 Argentina     1482216         0        40431          0
# 10                 Colombia     1399911         0        38484          0
# 11                  Germany     1296298     25866        21773        540
# 12                   Mexico     1217126     11897       112326        671
# 13                   Poland     1115201     13110        22174        544
# 14                     Iran     1092407      9384        51727        232
# 15                     Peru      979111         0        36499          0
# 16                  Ukraine      872228     13514        14755        285
# 17             South Africa      845083      8319        22952        205
# 18                Indonesia      605243      6310        18511        175
# 19                  Belgium      600397      2754        17692         89
# 20              Netherlands      594523      8838         9966         64
# 21                     Iraq      572600      1347        12549         23
# 22                  Czechia      569205      5864         9341         57
# 23                    Chile      567974      1534        15782          8
# 24                  Romania      545567      6460        13116        168
# 25               Bangladesh      487849      1884         6986         19
# 26              Philippines      447039      1504         8709          8
# 27                   Canada      446361      4292        13222        113
# 28                 Pakistan      432327      3047         8653         50
# 29                  Morocco      394564      3035         6542         50
# ..                      ...         ...       ...          ...        ...
# 190                Barbados         291         0            7          0
# 191             Saint Lucia         274         3            4          1
# 192              Seychelles         187         3            0          0
# 193   Caribbean Netherlands         172         0            3          0
# 194                St Barth         162         0            1          0
# 195                  Brunei         152         0            3          0
# 196     Antigua and Barbuda         147         1            4          0
# 197   St Vincent Grenadines          94         3            0          0
# 198                Dominica          87         2            0          0
# 199  British Virgin Islands          75         0            1          0
# 200                   Macao          46         0            0          0
# 201                    Fiji          44         0            2          0
# 202                 Grenada          43         0            0          0
# 203                    Laos          41         0            0          0
# 204           New Caledonia          36         0            0          0
# 205             Timor-Leste          31         0            0          0
# 206            Vatican City          27         0            0          0
# 207   Saint Kitts and Nevis          26         0            0          0
# 208               Greenland          19         0            0          0
# 209        Falkland Islands          17         0            0          0
# 11     30494036   363443    83903248
# 12      3118237    24073   129532213
# 13      6620376   175012    37828086
# 14      6611783    78276    84467718
# 15      5217086   157262    33174480
# 16      4957299   113658    43615882
# 17      5779544    96909    59638974
# 18      6271943    22823   274803482
# 19      6231437   536635    11612063
# 20      5077285   296021    17151770
# 21      3837024    94467    40617505
# 22      3294949   307427    10717838
# 23      5686946   296366    19188940
# 24      4386813   228717    19180085
# 25      2944252    17799   165415819
# 26      6154475    55836   110224876
# 27     12317829   325105    37888820
# 28      5948742    26703   222774877
# 29      4161069   112146    37103931
# ..          ...      ...         ...
# 190       52152   181378      287532
# 191       17231    93647      184000
# 192        5200    52729       98617
# 193        3873   147089       26331
# 194        5315   537412        9890
# 195       77829   177152      439334
# 196        5126    52152       98289
# 197       11720   105493      111097
# 198        6175    85685       72066
# 199        8846   291755       30320
# 200        4238     6488      653241
# 201       17576    19543      899328
# 202        6252    55448      112755
# 203       83753    11438     7322111
# 204       18012    62822      286714
# 205       14932    11232     1329471
# 206           0        0         802
# 207        4358    81662       53366
# 208       13742   241877       56814
# 209        4746  1346765        3524
# 210        4500     6482      694241
# 211        2946   509600        5781
# 212         626   125376        4993
# 213           0        0      603753
# 214        2651   176006       15062
# 215           0        0           0
# 216           0        0       59367
# 217        1149   103049       11150
# 218           0        0      198999
# 219           0        0      310283
#
# [220 rows x 13 columns]

# %%
data_df = pd.DataFrame(['SeriousCases','NewCases'])['Population'].sum().reset_index()
data_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:8543)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# C:\Users\lenovo\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4363)()
#
# KeyError: 'Population'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:8543)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-d9583ebf384b> in <module>()
# ----> 1 data_df = pd.DataFrame(['SeriousCases','NewCases'])['Population'].sum().reset_index()
#       2 data_df
#
# C:\Users\lenovo\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Users\lenovo\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\Users\lenovo\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# C:\Users\lenovo\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\lenovo\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4363)()
#
# KeyError: 'Population'
